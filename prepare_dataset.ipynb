# %%
import pandas as pd

# %%
economic_data = pd.read_excel('dataset/unprepared_dataset/BRICS Economic Data.xlsx')
education_data = pd.read_excel('dataset/unprepared_dataset/BRICS Education and Environment Data.xlsx')
health_data = pd.read_excel('dataset/unprepared_dataset/BRICS Health and Poverty Data.xlsx')
private_sector_data = pd.read_excel('dataset/unprepared_dataset/BRICS Private Sector Data.xlsx')
public_sector_data = pd.read_excel('dataset/unprepared_dataset/BRICS Public Sector and Society Data.xlsx')
datasets = [economic_data, education_data, health_data, private_sector_data, public_sector_data]

# %%
prepared_datasets = []
attribute_values = [345, 285, 277, 168, 319]
for dataset, attribute_value in zip(datasets, attribute_values):
    dataset = dataset.drop(labels=['Country Name', 'Country Code', 'Series Name'], axis=1)
    condition = (pd.isna(dataset['Series Code']))
    dataset = dataset.drop(dataset[condition].index)
    dataset = pd.concat([
        dataset.iloc[:attribute_value, :].reset_index().transpose(),
        dataset.iloc[attribute_value:attribute_value*2, :].reset_index().transpose(),
        dataset.iloc[attribute_value*2:attribute_value*3, :].reset_index().transpose(),
        dataset.iloc[attribute_value*3:attribute_value*4, :].reset_index().transpose(),
        dataset.iloc[attribute_value*4:, :].reset_index().transpose()
    ], ignore_index=True).drop(labels=[0, 53, 54, 106, 107, 159, 160, 212, 213], axis=0)
    prepared_datasets.append(dataset)

# %%
main_dataset = pd.concat(prepared_datasets, axis=1).reset_index().iloc[:, 1:]
main_dataset
# Out:
#                    0                    1                    2    \
# 0    NY.ADJ.NNTY.KD.ZG       NY.ADJ.NNTY.KD       NY.ADJ.NNTY.CD
# 1                  NaN  308554905378.880432   38799440792.935898
# 2             11.64947  344499916279.819092   45244303462.111702
# 3            12.344548  387026874506.892334   53813384465.657799
# 4            11.992465  433440935297.989868   72178679239.526306
# ..                 ...                  ...                  ...
# 251          -0.289369   261379294061.43338  241507035833.834991
# 252           2.644555  268291614395.350586  285772371552.637024
# 253          -0.358592  267329542519.672638   299491029449.79303
# 254           0.417111  268444602750.852417  284723341310.499023
# 255                NaN                  NaN                  NaN
#
#                       3                  4                  5    \
# 0    NY.ADJ.NNTY.PC.KD.ZG  NY.ADJ.NNTY.PC.KD  NY.ADJ.NNTY.PC.CD
# 1                     NaN        3244.094262         407.928808
# 2                 8.93544        3533.968346         464.125405
# 3                9.670966        3875.737209         538.891591
# 4                9.363915         4238.65796         705.838395
# ..                    ...                ...                ...
# 251             -1.746295        4649.518309        4296.693424
# 252              1.200392        4705.360279        5012.692856
# 253             -1.708182        4644.421774        5182.176334
# 254              -0.89601        4597.557213        4862.222806
# 255                   NaN                NaN                NaN
#
#                    6                 7                  8                 9    \
# 0    NY.ADJ.SVNX.GN.ZS    NY.ADJ.SVNX.CD  NY.ADJ.SVNG.GN.ZS    NY.ADJ.SVNG.CD
# 1                  NaN               NaN                NaN               NaN
# 2                  NaN               NaN                NaN               NaN
# 3                  NaN               NaN                NaN               NaN
# 4                  NaN               NaN                NaN               NaN
# ..                 ...               ...                ...               ...
# 251           0.652777  1881087181.38016           0.159571  459832130.915643
# 252            1.70025  5765053300.62488            1.21908  4133545546.66279
# 253           0.271589  968619743.668668          -0.209581  -747468063.73103
# 254          -0.288157 -984123511.536506           -0.75462 -2577200301.00945
# 255                NaN               NaN                NaN               NaN
#
#      ...                309                   310             311  \
# 0    ...  SL.UEM.1524.MA.ZS  SL.UEM.1524.MA.NE.ZS  SL.UEM.1524.ZS
# 1    ...                NaN                   NaN             NaN
# 2    ...                NaN                   NaN             NaN
# 3    ...                NaN                   NaN             NaN
# 4    ...                NaN                   NaN             NaN
# ..   ...                ...                   ...             ...
# 251  ...          48.949001                 48.59       53.683998
# 252  ...          49.165001                 48.82       53.532001
# 253  ...          49.493999             49.150002       53.744999
# 254  ...          53.561001             53.220001       57.379002
# 255  ...             55.688                 55.43       59.618999
#
#                    312                313                314             315  \
# 0    SL.UEM.1524.NE.ZS  SL.EMP.VULN.FE.ZS  SL.EMP.VULN.MA.ZS  SL.EMP.VULN.ZS
# 1                  NaN                NaN                NaN             NaN
# 2                  NaN                NaN                NaN             NaN
# 3                  NaN                NaN                NaN             NaN
# 4                  NaN                NaN                NaN             NaN
# ..                 ...                ...                ...             ...
# 251          53.349998                9.7                9.5            9.59
# 252          53.200001              10.22               9.69            9.93
# 253              53.41              10.24              10.39           10.32
# 254          57.049999              10.59              10.73           10.67
# 255          59.360001                NaN                NaN             NaN
#
#                    316                317             318
# 0    SL.EMP.WORK.FE.ZS  SL.EMP.WORK.MA.ZS  SL.EMP.WORK.ZS
# 1                  NaN                NaN             NaN
# 2                  NaN                NaN             NaN
# 3                  NaN                NaN             NaN
# 4                  NaN                NaN             NaN
# ..                 ...                ...             ...
# 251          87.660004          82.760002       84.879997
# 252          87.019997          82.589996       84.529999
# 253          87.459999          82.050003           84.43
# 254          86.690002          81.269997       83.660004
# 255                NaN                NaN             NaN
#
# [256 rows x 1394 columns]

# %%
main_dataset = main_dataset.set_axis(main_dataset.iloc[0:1, :].values.tolist()[0], axis=1)
main_dataset = main_dataset.iloc[1:, :].reset_index().iloc[:, 1:]
main_dataset
# Out:
#     NY.ADJ.NNTY.KD.ZG       NY.ADJ.NNTY.KD       NY.ADJ.NNTY.CD  \
# 0                 NaN  308554905378.880432   38799440792.935898
# 1            11.64947  344499916279.819092   45244303462.111702
# 2           12.344548  387026874506.892334   53813384465.657799
# 3           11.992465  433440935297.989868   72178679239.526306
# 4            5.131874  455684576860.778931   95496328254.079498
# ..                ...                  ...                  ...
# 250         -0.289369   261379294061.43338  241507035833.834991
# 251          2.644555  268291614395.350586  285772371552.637024
# 252         -0.358592  267329542519.672638   299491029449.79303
# 253          0.417111  268444602750.852417  284723341310.499023
# 254               NaN                  NaN                  NaN
#
#     NY.ADJ.NNTY.PC.KD.ZG NY.ADJ.NNTY.PC.KD NY.ADJ.NNTY.PC.CD  \
# 0                    NaN       3244.094262        407.928808
# 1                8.93544       3533.968346        464.125405
# 2               9.670966       3875.737209        538.891591
# 3               9.363915        4238.65796        705.838395
# 4               2.675231       4352.051841        912.040879
# ..                   ...               ...               ...
# 250            -1.746295       4649.518309       4296.693424
# 251             1.200392       4705.360279       5012.692856
# 252            -1.708182       4644.421774       5182.176334
# 253             -0.89601       4597.557213       4862.222806
# 254                  NaN               NaN               NaN
#
#     NY.ADJ.SVNX.GN.ZS    NY.ADJ.SVNX.CD NY.ADJ.SVNG.GN.ZS    NY.ADJ.SVNG.CD  \
# 0                 NaN               NaN               NaN               NaN
# 1                 NaN               NaN               NaN               NaN
# 2                 NaN               NaN               NaN               NaN
# 3                 NaN               NaN               NaN               NaN
# 4                 NaN               NaN               NaN               NaN
# ..                ...               ...               ...               ...
# 250          0.652777  1881087181.38016          0.159571  459832130.915643
# 251           1.70025  5765053300.62488           1.21908  4133545546.66279
# 252          0.271589  968619743.668668         -0.209581  -747468063.73103
# 253         -0.288157 -984123511.536506          -0.75462 -2577200301.00945
# 254               NaN               NaN               NaN               NaN
#
#      ... SL.UEM.1524.MA.ZS SL.UEM.1524.MA.NE.ZS SL.UEM.1524.ZS  \
# 0    ...               NaN                  NaN            NaN
# 1    ...               NaN                  NaN            NaN
# 2    ...               NaN                  NaN            NaN
# 3    ...               NaN                  NaN            NaN
# 4    ...               NaN                  NaN            NaN
# ..   ...               ...                  ...            ...
# 250  ...         48.949001                48.59      53.683998
# 251  ...         49.165001                48.82      53.532001
# 252  ...         49.493999            49.150002      53.744999
# 253  ...         53.561001            53.220001      57.379002
# 254  ...            55.688                55.43      59.618999
#
#     SL.UEM.1524.NE.ZS SL.EMP.VULN.FE.ZS SL.EMP.VULN.MA.ZS SL.EMP.VULN.ZS  \
# 0                 NaN               NaN               NaN            NaN
# 1                 NaN               NaN               NaN            NaN
# 2                 NaN               NaN               NaN            NaN
# 3                 NaN               NaN               NaN            NaN
# 4                 NaN               NaN               NaN            NaN
# ..                ...               ...               ...            ...
# 250         53.349998               9.7               9.5           9.59
# 251         53.200001             10.22              9.69           9.93
# 252             53.41             10.24             10.39          10.32
# 253         57.049999             10.59             10.73          10.67
# 254         59.360001               NaN               NaN            NaN
#
#     SL.EMP.WORK.FE.ZS SL.EMP.WORK.MA.ZS SL.EMP.WORK.ZS
# 0                 NaN               NaN            NaN
# 1                 NaN               NaN            NaN
# 2                 NaN               NaN            NaN
# 3                 NaN               NaN            NaN
# 4                 NaN               NaN            NaN
# ..                ...               ...            ...
# 250         87.660004         82.760002      84.879997
# 251         87.019997         82.589996      84.529999
# 252         87.459999         82.050003          84.43
# 253         86.690002         81.269997      83.660004
# 254               NaN               NaN            NaN
#
# [255 rows x 1394 columns]

# %%
main_dataset = main_dataset.drop(labels=[
    'NY.ADJ.NNTY.KD',







], axis=1)
main_dataset

"""
TODO Удалить дубликаты признаков
NY.ADJ.NNTY.KD
NY.ADJ.NNTY.PC.KD


"""
# Out:
#     NY.ADJ.NNTY.KD.ZG       NY.ADJ.NNTY.KD       NY.ADJ.NNTY.CD  \
# 0                 NaN  308554905378.880432   38799440792.935898
# 1            11.64947  344499916279.819092   45244303462.111702
# 2           12.344548  387026874506.892334   53813384465.657799
# 3           11.992465  433440935297.989868   72178679239.526306
# 4            5.131874  455684576860.778931   95496328254.079498
# ..                ...                  ...                  ...
# 250         -0.289369   261379294061.43338  241507035833.834991
# 251          2.644555  268291614395.350586  285772371552.637024
# 252         -0.358592  267329542519.672638   299491029449.79303
# 253          0.417111  268444602750.852417  284723341310.499023
# 254               NaN                  NaN                  NaN
#
#     NY.ADJ.NNTY.PC.KD.ZG NY.ADJ.NNTY.PC.KD NY.ADJ.NNTY.PC.CD  \
# 0                    NaN       3244.094262        407.928808
# 1                8.93544       3533.968346        464.125405
# 2               9.670966       3875.737209        538.891591
# 3               9.363915        4238.65796        705.838395
# 4               2.675231       4352.051841        912.040879
# ..                   ...               ...               ...
# 250            -1.746295       4649.518309       4296.693424
# 251             1.200392       4705.360279       5012.692856
# 252            -1.708182       4644.421774       5182.176334
# 253             -0.89601       4597.557213       4862.222806
# 254                  NaN               NaN               NaN
#
#     NY.ADJ.SVNX.GN.ZS    NY.ADJ.SVNX.CD NY.ADJ.SVNG.GN.ZS    NY.ADJ.SVNG.CD  \
# 0                 NaN               NaN               NaN               NaN
# 1                 NaN               NaN               NaN               NaN
# 2                 NaN               NaN               NaN               NaN
# 3                 NaN               NaN               NaN               NaN
# 4                 NaN               NaN               NaN               NaN
# ..                ...               ...               ...               ...
# 250          0.652777  1881087181.38016          0.159571  459832130.915643
# 251           1.70025  5765053300.62488           1.21908  4133545546.66279
# 252          0.271589  968619743.668668         -0.209581  -747468063.73103
# 253         -0.288157 -984123511.536506          -0.75462 -2577200301.00945
# 254               NaN               NaN               NaN               NaN
#
#      ... SL.UEM.1524.MA.ZS SL.UEM.1524.MA.NE.ZS SL.UEM.1524.ZS  \
# 0    ...               NaN                  NaN            NaN
# 1    ...               NaN                  NaN            NaN
# 2    ...               NaN                  NaN            NaN
# 3    ...               NaN                  NaN            NaN
# 4    ...               NaN                  NaN            NaN
# ..   ...               ...                  ...            ...
# 250  ...         48.949001                48.59      53.683998
# 251  ...         49.165001                48.82      53.532001
# 252  ...         49.493999            49.150002      53.744999
# 253  ...         53.561001            53.220001      57.379002
# 254  ...            55.688                55.43      59.618999
#
#     SL.UEM.1524.NE.ZS SL.EMP.VULN.FE.ZS SL.EMP.VULN.MA.ZS SL.EMP.VULN.ZS  \
# 0                 NaN               NaN               NaN            NaN
# 1                 NaN               NaN               NaN            NaN
# 2                 NaN               NaN               NaN            NaN
# 3                 NaN               NaN               NaN            NaN
# 4                 NaN               NaN               NaN            NaN
# ..                ...               ...               ...            ...
# 250         53.349998               9.7               9.5           9.59
# 251         53.200001             10.22              9.69           9.93
# 252             53.41             10.24             10.39          10.32
# 253         57.049999             10.59             10.73          10.67
# 254         59.360001               NaN               NaN            NaN
#
#     SL.EMP.WORK.FE.ZS SL.EMP.WORK.MA.ZS SL.EMP.WORK.ZS
# 0                 NaN               NaN            NaN
# 1                 NaN               NaN            NaN
# 2                 NaN               NaN            NaN
# 3                 NaN               NaN            NaN
# 4                 NaN               NaN            NaN
# ..                ...               ...            ...
# 250         87.660004         82.760002      84.879997
# 251         87.019997         82.589996      84.529999
# 252         87.459999         82.050003          84.43
# 253         86.690002         81.269997      83.660004
# 254               NaN               NaN            NaN
#
# [255 rows x 1394 columns]

# %%
main_dataset.to_excel(r'dataset/prepared_dataset/BRICS_all_areas_prepared_dataset.xlsx')
